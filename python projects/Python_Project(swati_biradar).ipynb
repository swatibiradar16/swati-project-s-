# %%
print("----------------------------")
print('      Welcome to Mall ')
print("----------------------------")
class m:
    def __init__(self,n):
        self.name=n
    def show_name(self):
        print("Custumer name is : ",self.name)
name=input("enter Your name :")
a= m(name)
a.show_name()

class Mall() :
    
    
    def mall_menu() :
        print("[1] ground floor ")
        print("[2] First floor ")
        print("[3] Second floor ")
        print("[0] exit from mall ")
    
    mall_menu()
    optionn=int(input("Enter "))
    while optionn !=0:
        if optionn ==1:            
            def gr_menu() :
                print("-------------------------------")
                print('   Entering Department store') 
                print("-------------------------------")
                print("[1] Clothes shop")
                print("[2] Shoes shop ")
                print("[0] exit Department store ")       
            gr_menu()
            option1=int(input("Enter "))
            while option1 !=0:
                if option1 ==1:
#clothes menu
                  
                    def clothes_menu():
                        print("-------------------------------")
                        print(" * Entering Clothes Section * ")
                        print("-------------------------------")
                        print("[1] Traditional dress")
                        print("[2] Formal dress ")
                        print("[3] Casual dress ")
                        print("[0] exit clothes shop ")       
                    clothes_menu()
                    option2=int(input("Enter "))                                       
                    bill=[]
                    List=[]
                    Bill=0
                    while option2 !=0:
# Start traditional
                        if option2 ==1:
                            print("---------------------------------")
                            print("* Entering Traditional Section *")
                            print("----------------------------------")
                            print('[1] Lehenga ')
                            print('[2] Kurta')
                            print("[0] exit from traditional section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print(" Lehenga of price 10000 rs")
                                    List.append('lehn')
                                    bill.append(10000)
                                    Bill+=10017
                                elif option3==2: 
                                    print(" Kurta of price 2000 rs")
                                    List.append('Kurta')
                                    bill.append(2000)
                                    Bill+=2017
                                break
                            print()
                            clothes_menu()
                            option2=int(input("Enter "))
                            
 # Formal dress start
                        elif option2 == 2:
                            print("-------------------------------")
                            print(" * Entering Formal Section *")
                            print("-------------------------------")
                            print('[1] Kurti ')
                            print('[2] Shirt ')
                            print("[0] exit from Formal section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print(" kurti of price 2000 rs")
                                    List.append('Kurti')
                                    bill.append(2000)
                                    Bill+=2017
                                elif option3==2: 
                                    print("get Saree of price 500 rs")
                                    List.append('Saree')
                                    bill.append(500)
                                    Bill+=517
                                break
                            print()
                            clothes_menu()
                            option2=int(input("Enter "))
                            
                            
# foramal dress end:- 
#Casual dress start:-             
                        elif option2 == 3:
                            print("-------------------------------")
                            print("  * Entering Casual Section *")
                            print("-------------------------------")
                            print('[1] Sweatshirt')
                            print('[2] T-Shirt  ')
                            print("[0] exit from Casual section")
                            option3=int(input("Enter "))
                            
                            while option3!=0:
                                if option3==1:
                                    print(" Sweatshirt of price 1000 rs")
                                    List.append('Sshirt')
                                    bill.append(1000)
                                    Bill+=1017
                                else:
                                    print("get T-Shirt of price 500 rs")
                                    List.append('Tshirt')
                                    bill.append(500)
                                    Bill+=517
                                break
                            print()
                            clothes_menu()
                            option2=int(input("Enter "))
                
                    
                    print("Exiting from cloth section")
                    print('______________________________________________')
                    print('|             - - - - -                      |')
                    print('|             *  bill *                      |')
                    print('|             - - - - -                      |')
                    print('|       My MALL, near xyz pune 46            |')
                    print('|       Tel No : 0123-12345                  |')
                    print('|       HELPLINE : 100 200 3000              |')
                    print('|                                            |')
                    print('|--------------------------------------------|')
                    print('|                                            |')
                    print('| Item         base Amt       Net Amt        |')
                    print('|                             GST 17%        |')
                    print('|--------------------------------------------|')
                    i=0
                    j=0
                    while i  <len(bill):
  
                        while j<len(List):
                            a=List[j]
                            j+=1
    
                            break

                        b=bill[i]
                        print('| ',a,end ='      '    ,                     )
                        print(' ',b,end ='         '    ,                     )
                        print(' ',b+17   ,         "     "            ,  )
                        i=i+1
                    print("|--------------------------------------------|")
                    print("| Total : ",'                        ' ,Bill,'   |')
                    print('|--------------------------------------------|')        
                    print()
                    print()
                    print()    
                    print()    
                    
                    
                    
                    gr_menu()
                    option1=int(input("Enter "))

# Shoes menu start
                                                       
                elif option1==2:
                    def shoes_menu():
                        print("-------------------------------")
                        print("     entering Shoes Store")
                        print("-------------------------------")
                        print("[1] Bata")
                        print("[2] Wood land")
                        print("[3] Pumma")
                        print('[4] Nicky')
                        print('[5] Adidas')
                        print('[0] Exit from shoes store')
                    shoes_menu()
                    option4=int(input('Enter number'))
                    List=[]
                    bill=[]
                    Bill=0
                    while option4 !=0:
                        if option4==1:
                            print("Get Bata shoes of price 1000")
                            List.append('Bata')
                            bill.append(1000)
                            Bill+=1020
                    

                        elif option4==2:
                            print("Get Wood land shoes of price 1000")
                            List.append('WLan')
                            bill.append(1000)
                            Bill+=1020
            
                        elif option4==3:
                            print("Get Pumma shoes of price 1000")
                            List.append('Pumm')
                            bill.append(1000)
                            Bill+=1020

                        elif option4==4:
                            print("Get Nicky land shoes of price 1000")
                            List.append('Nicky')
                            bill.append(1000)
                            Bill+=1020

                        elif option4 == 5:
                            print('Get Adidas shoes of price 1000')
                            List.append('Adi..')
                            bill.append(1000)
                            Bill+=1020
                        else:
                            print('invalid syntax')
                        shoes_menu()
                        option4=int(input('Enter number'))
                  
                    print("Exiting from shoes section")
                    print('______________________________________________')
                    print('|             - - - - -                      |')
                    print('|             *  bill *                      |')
                    print('|             - - - - -                      |')
                    print('|       My MALL, near xyz pune 46            |')
                    print('|       Tel No : 0123-12345                  |')
                    print('|       HELPLINE : 100 200 3000              |')
                    print('|                                            |')
                    print('|--------------------------------------------|')
                    print('|                                            |')
                    print('| Item         base Amt       Net Amt        |')
                    print('|                             GST 20%        |')
                    print('|--------------------------------------------|')
                    i=0
                    j=0
                    while i  <len(bill):
  
                        while j<len(List):
                            a=List[j]
                            j+=1
    
                            break

                        b=bill[i]
                        print('| ',a,end ='      '    ,                     )
                        print(' ',b,end ='         '    ,                     )
                        print(' ',b+20   ,         "     "            ,  )
                        i=i+1
                    print("|--------------------------------------------|")
                    print("| Total : ",'                        ',Bill,'|')
                    print('|--------------------------------------------|')        
                    print()
                    print()
                    print()    
                    print()    
                    
                    
                    
                    gr_menu()
                    option1=int(input("Enter "))
                    



                  
                

                


#if option1==0:
            print("Exiting from departent Store")
            mall_menu()
            optionn=int(input("Enter "))


# Entering First floor
        elif optionn==2:
            def first_menu() :
                print("-------------------------------")
                print('     Entering First Floor')  
                print("-------------------------------")
                print("[1] Grocery")
                print("[2] Restorent  ")
                print("[0] exit from First floor ")       
            first_menu()
            option1=int(input("Enter "))
            while option1 !=0:
                if option1 ==1:
#Grocery menu
                  
                    def Grocery_menu():
                        print("-------------------------------")
                        print(" * Entering Grocery Section * ")
                        print("-------------------------------")
                        print("[1] DAIRY")
                        print("[2] PRODUCE ")
                        print("[3] PRESERVES ")
                        print("[0] exit Grocery shop ")       
                    Grocery_menu()
                    option2=int(input("Enter "))                                       
                    List=[]
                    bill=[]
                    Bill=0
                    while option2 !=0:
# Start grocery:-
                        if option2 ==1:
                            print("-------------------------------")
                            print(" * Entering dairy Section *")
                            print("-------------------------------")
                            print('[1] milk ')
                            print('[2] cheese')
                            print("[0] exit from dairy section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print("get milk of price 56 rs")
                                    List.append('Milk')
                                    bill.append(56)
                                    Bill+=61
                                elif option3==2: 
                                    print("get cheese of price 400 rs")
                                    List.append('Chee..')
                                    bill.append(400)
                                    Bill+=405
                                break
                            print()
                            Grocery_menu()
                            option2=int(input("Enter "))
                            
 # Produce:-
                        elif option2 == 2:
                            print("--------------------------------")
                            print(" * Entering produce Section *")
                            print("-------------------------------")
                            print('[1] potatoes ')
                            print('[2] carrots ')
                            print("[0] exit from produce section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print("get pototoes of price 50 rs")
                                    List.append('Poto..')
                                    bill.append(50)
                                    Bill+=55
                                elif option3==2: 
                                    print("get carrots of price 60 rs")
                                    List.append('carr..')
                                    bill.append(60)
                                    Bill+=65
                                break
                            print()
                            Grocery_menu()
                            option2=int(input("Enter "))
                            
                            
#preserves:-            
                        elif option2 == 3:
                            print("-------------------------------")
                            print("* Entering preserve Section *")
                            print("-------------------------------")
                            print('[1] cooking oil')
                            print('[2] honey ')
                            print("[0] exit from preserves section")
                            option3=int(input("Enter "))
                            
                            while option3!=0:
                                if option3==1:
                                    print("get cooking oil of price 200 rs")
                                    List.append('oil')
                                    bill.append(200)
                                    Bill+=205
                                else:
                                    print("get honey of price 700 rs")
                                    List.append('honey')
                                    bill.append(700)
                                    Bill+=705
                                break
                                print()
                            Grocery_menu()
                            option2=int(input("Enter "))
                
                    
                    print("Exiting from grocery section")
                    print('______________________________________________')
                    print('|             - - - - -                      |')
                    print('|             *  bill *                      |')
                    print('|             - - - - -                      |')
                    print('|       My MALL, near xyz pune 46            |')
                    print('|       Tel No : 0123-12345                  |')
                    print('|       HELPLINE : 100 200 3000              |')
                    print('|                                            |')
                    print('|--------------------------------------------|')
                    print('|                                            |')
                    print('| Item         base Amt       Net Amt        |')
                    print('|                             GST 5%         |')
                    print('|--------------------------------------------|')
                    i=0
                    j=0
                    while i  <len(bill):
  
                        while j<len(List):
                            a=List[j]
                            j+=1
    
                            break

                        b=bill[i]
                        print('| ',a,end ='      '    ,                     )
                        print(' ',b,end ='         '    ,                     )
                        print(' ',b+5   ,         "     "            ,  )
                        i=i+1
                    print("|--------------------------------------------|")
                    print("| Total : ",'                        ',Bill,'  |')
                    print('|--------------------------------------------|')        
                    print()
                    print()
                    print()    
                    print()    
                    
                    first_menu()
                    option1=int(input("Enter "))

# Restaurants menu start
                elif option1==2:
                  
                    def rest_menu():
                        print("----------------------------------")
                        print("* Entering restaurants Section *")
                        print("----------------------------------")
                        print("[1] veg")
                        print("[2] non_veg ")
                        print("[0] exit restaurants  ")       
                    rest_menu()
                    option2=int(input("Enter "))                                       
                    List=[]
                    bill=[]
                    Bill=0
                    while option2 !=0:
# veg :-
                        if option2 ==1:
                            print("--------------------------------")
                            print("  * Entering veg Section *")
                            print("--------------------------------")
                            print('[1] veg_curries')
                            print('[2] veg_rice')
                            print('[3] roti')
                            print("[0] exit from veg section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print("get veg_curries of price 150 rs")
                                    List.append('v_cur')
                                    bill.append(150)
                                    Bill+=168
                                elif option3==2: 
                                    print("get veg_rice of price 100 rs")
                                    List.append('veg_ric')
                                    bill.append(100)
                                    Bill+=118
                                else: 
                                    print("get roti of price 20 rs")
                                    List.append('Roti..')
                                    bill.append(20)
                                    Bill+=28
                                break
                            print()
                            rest_menu()
                            option2=int(input("Enter "))
                            
 # non_veg:-
                        elif option2 == 2:
                            print("--------------------------------")
                            print(" * Entering produce Section *")
                            print("--------------------------------")
                            print('[1] birayani ')
                            print('[2] chicken roast ')
                            print('[3] fish currie')
                            print("[0] exit from non_veg section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print("get birayani of price 100 rs")
                                    List.append('Biray')
                                    bill.append(100)
                                    Bill+=118
                                elif option3==2: 
                                    print("get chicken roast of price 150 rs")
                                    List.append('C_rost')
                                    bill.append(150)
                                    Bill+=168
                                else:
                                    print("get fish currie of price 200")
                                    List.append('curri')
                                    bill.append(200)
                                    Bill+=218
                                break
                            print()
                            rest_menu()
                            option2=int(input("Enter "))
                            
                            
                   
                   
                    print('______________________________________________')
                    print('|             - - - - -                      |')
                    print('|             *  bill *                      |')
                    print('|             - - - - -                      |')
                    print('|       My MALL, near xyz pune 46            |')
                    print('|       Tel No : 0123-12345                  |')
                    print('|       HELPLINE : 100 200 3000              |')
                    print('|                                            |')
                    print('|--------------------------------------------|')
                    print('|                                            |')
                    print('| Item         base Amt       Net Amt        |')
                    print('|                             GST 18%        |')
                    print('|--------------------------------------------|')
                    i=0
                    j=0
                    while i  <len(bill):
  
                        while j<len(List):
                            a=List[j]
                            j+=1
    
                            break

                        b=bill[i]
                        print('| ',a,end ='      '    ,                     )
                        print(' ',b,end ='         '    ,                     )
                        print(' ',b+18   ,         "     "            ,  )
                        i=i+1
                    print("|--------------------------------------------|")
                    print("| Total : ",'                        ',Bill,'   |')
                    print('|--------------------------------------------|')        
                    print()
                    print()
                    print()    
                    print()    
                    print("Exiting from Restaurants")
                    first_menu()
                    option1=int(input("Enter "))



            

            print('Exiting from first floor')
            mall_menu()
            optionn=int(input("Enter "))
            
            
# End first floor 

# entering second floor:-
        elif optionn==3:
            def sec_menu() :
                print("--------------------------------")
                print('     Entering Second Floor')   
                print("--------------------------------")
                print("[1] theatre")
                print("[2]  Games  ")
                print("[0] exit from second floor ")       
            sec_menu()
            option1=int(input("Enter "))
            while option1 !=0:
                if option1 ==1:                       
                    def theatre_menu():
                        print("--------------------------------")
                        print(" * Entering theatre Section *")
                        print("--------------------------------")
                        print("[1] bollywood ")
                        print("[2] hollywood ")
                        print('[3] animated')
                        print("[0] exit theatre")       
                    theatre_menu()
                    option2=int(input("Enter "))                                       
                    List=[]
                    bill=[]
                    Bill=0
                    while option2 !=0:
# Bollywood :-
                        if option2 ==1:
                            print("--------------------------------")
                            print(" * Entering bollywood Section *")
                            print("--------------------------------")
                            print('[1] drishyam2')
                            print('[2] adipurush')
                            print('[3] brahmastra')
                            print("[0] exit from theatre section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print("get drishyam2 of price 500 rs")
                                    List.append('Drish2')
                                    bill.append(500)
                                    Bill+=506
                                elif option3==2: 
                                    print("get adipurush of price 700 rs")
                                    List.append('Adip')
                                    bill.append(700)
                                    Bill+=706
                                else: 
                                    print("get brahmastra of price 800 rs")
                                    List.append('Brahm')
                                    bill.append(800)
                                    Bill+=806
                                break
                            print()
                            theatre_menu()
                            option2=int(input("Enter "))
                            
 # hollywood:-
                        elif option2 == 2:
                            print("--------------------------------")
                            print("* Entering hollywood Section *")
                            print("--------------------------------")
                            print('[1] titanic ')
                            print('[2] avatar ')
                            print('[3] inception')
                            print("[0] exit from hollywood section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print("get titanic of price 400 rs")
                                    List.append('Tita')
                                    bill.append(400)
                                    Bill+=406
                                    print("get avatar of price 300 rs")
                                    List.append('Avatar')
                                    bill.append(300)
                                    Bill+=306
                                    print("get inception of price 700 rs")
                                    List.append('Ince')
                                    bill.append(700)
                                    Bill+=706
                                    break
                            print()
                            theatre_menu()
                            option2=int(input("Enter "))
# animated:-           
                        elif option2==3:
                            print("--------------------------------")
                            print(" * Entering animated Section *")
                            print("--------------------------------")
                            print('[1] ratatoulle ')
                            print('[2] encanto ')
                            print('[3] coco')
                            print("[0] exit from hollywood section")
                            option3=int(input("Enter "))
                            while option3!=0:
                                if option3==1:
                                    print("get ratatoulle of price 400 rs")
                                    List.append('Rata.')
                                    bill.append(400)
                                    Bill+=406
                                    print("get encanto of price 300 rs")
                                    List.append('Enca.')
                                    bill.append(300)
                                    Bill+=306
                                    print("get coco of price 700 rs")
                                    List.append('Coco')
                                    bill.append(700)
                                    Bill+=706
                                    break
                            print()
                            theatre_menu()
                            option2=int(input("Enter "))
                            
                    
                    print('______________________________________________')
                    print('|             - - - - -                      |')
                    print('|             *  bill *                      |')
                    print('|             - - - - -                      |')
                    print('|       My MALL, near xyz pune 46            |')
                    print('|       Tel No : 0123-12345                  |')
                    print('|       HELPLINE : 100 200 3000              |')
                    print('|                                            |')
                    print('|--------------------------------------------|')
                    print('|                                            |')
                    print('| Item         base Amt       Net Amt        |')
                    print('|                             GST 6%         |')
                    print('|--------------------------------------------|')
                    i=0
                    j=0
                    while i  <len(bill):
  
                        while j<len(List):
                            a=List[j]
                            j+=1
    
                            break

                        b=bill[i]
                        print('| ',a,end ='      '    ,                     )
                        print(' ',b,end ='         '    ,                     )
                        print(' ',b+6   ,         "     "            ,  )
                        i=i+1
                    print("|--------------------------------------------|")
                    print("| Total : ",'                        ',Bill,'   |')
                    print('|--------------------------------------------|')        
                    print()
                    print()
                    print()    
                    print()    
                    
                    print("Exiting from Theatre")
                    sec_menu()
                    option1=int(input("Enter "))    
                                
                        
                elif option1==2:
                    print('Coming Soon')
                    break
                    
            
            print("Exit From Second floor")  
            mall_menu()
            optionn=int(input("Enter "))

        else:
            print("Choose valid option")
            mall_menu()
            optionn=int(input("Enter "))
    print("-----------------------------------------")        
    print("  Exit from mall thank you for shoping")
    print("-----------------------------------------")
# Out:
# ----------------------------
#       Welcome to Mall
# ----------------------------
# enter Your name :abc
# Custumer name is :  abc
# [1] ground floor
# [2] First floor
# [3] Second floor
# [0] exit from mall
# Enter 3
# --------------------------------
#      Entering Second Floor
# --------------------------------
# [1] theatre
# [2]  Games
# [0] exit from second floor
# Enter 1
# --------------------------------
#  * Entering theatre Section *
# --------------------------------
# [1] bollywood
# [2] hollywood
# [3] animated
# [0] exit theatre
# Enter 2
# --------------------------------
# * Entering hollywood Section *
# --------------------------------
# [1] titanic
# [2] avatar
# [3] inception
# [0] exit from hollywood section
# Enter 1
# get titanic of price 400 rs
# get avatar of price 300 rs
# get inception of price 700 rs
#
# --------------------------------
#  * Entering theatre Section *
# --------------------------------
# [1] bollywood
# [2] hollywood
# [3] animated
# ...
